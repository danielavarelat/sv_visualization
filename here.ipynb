# %% [markdown]
# # GRID VISUALIZATION - STATIC IMAGE

# %%
import create_grid

# %%
outdir="/home/varelad/outdir_716"
samples_ids=["I-H-134716-N1-1-D1-1", "I-H-134716-N2-1-D1-1","I-H-134716-T1-1-D1-1","I-H-134716-T2-1-D1-1" ]

# %%
df_out=create_grid.get_df_full(outdir, samples_ids)
df_out
# Out:
#                names_files                                    svs  chr1  \
# 0    6_31358899_6_31455872    <SV> DUP DUP(6:31358899-6:31455872)     6
# 1  12_96233590_17_47502142  <SV> TRA TRA(12:96233590-17:47502142)    12
# 2    19_2206424_19_2210815    <SV> DEL DEL(19:2206424-19:2210815)    19
# 3  21_11033689_21_11039238  <SV> DEL DEL(21:11033689-21:11039238)    21
#
#      start1      end1  chr2    start2      end2                          name  \
# 0  31358898  31358899     6  31455871  31455872    DUP(6:31358899-6:31455872)
# 1  96233589  96233590    17  47502141  47502142  TRA(12:96233590-17:47502142)
# 2   2206423   2206424    19   2210814   2210815    DEL(19:2206424-19:2210815)
# 3  11033688  11033689    21  11039237  11039238  DEL(21:11033689-21:11039238)
#
#    score      ...      COV I-H-134716-N2-1-D1-1 COV I-H-134716-T1-1-D1-1  \
# 0    100      ...                    (69L, 48L)              (144L, 48L)
# ...

# %%
df_svs, df_path, dict_annotation=create_grid.make_grids(outdir, samples_ids, df_out)
df_svs
# Out:
#                                  SAMPLE ID  \
# I-H-134716-N1-1-D1-1  I-H-134716-N1-1-D1-1
# I-H-134716-N2-1-D1-1  I-H-134716-N2-1-D1-1
# I-H-134716-T1-1-D1-1  I-H-134716-T1-1-D1-1
# I-H-134716-T2-1-D1-1  I-H-134716-T2-1-D1-1
# annotation
#
#                                                             CIRCOS PLOT  \
# I-H-134716-N1-1-D1-1  /home/varelad/outdir_716/I-H-134716-N1-1-D1-1/...
# I-H-134716-N2-1-D1-1  /home/varelad/outdir_716/I-H-134716-N2-1-D1-1/...
# I-H-134716-T1-1-D1-1  /home/varelad/outdir_716/I-H-134716-T1-1-D1-1/...
# I-H-134716-T2-1-D1-1  /home/varelad/outdir_716/I-H-134716-T2-1-D1-1/...
# annotation
#
#                                              DUP(6:31358899-6:31455872)  \
# I-H-134716-N1-1-D1-1  [I-H-134716-N1-1-D1-1, DUP(6:31358899-6:314558...
# I-H-134716-N2-1-D1-1  [I-H-134716-N2-1-D1-1, DUP(6:31358899-6:314558...
# I-H-134716-T1-1-D1-1  [I-H-134716-T1-1-D1-1, DUP(6:31358899-6:314558...
# ...

# %% [markdown]
# # Selecting specific svs and samples

# %%
samples_show=["I-H-134716-N1-1-D1-1", "I-H-134716-N2-1-D1-1","I-H-134716-T1-1-D1-1","I-H-134716-T2-1-D1-1" ]
selected_svs=["DUP(6:31358899-6:31455872)", "TRA(12:96233590-17:47502142)"]

# %%
result1=create_grid.create_imagen(outdir, samples_show, selected_svs, df_out, df_path, dict_annotation)
result1
# Out:
# <PIL.Image.Image image mode=RGB size=3200x4200 at 0x7FAD74600C18>

# %% [markdown]
# # Show all

# %%
list_svs = df_out["name"].tolist()
result2=create_grid.create_imagen(outdir, samples_ids, list_svs, df_out, df_path, dict_annotation)
result2
# Out:
# <PIL.Image.Image image mode=RGB size=5200x4200 at 0x7FAD712D37B8>

# %% [markdown]
# # SAME IMAGE

# %%
name_result=result1
img_path="/home/varelad/test.png"
name_result.save(img_path)

# %%
outdir=



df_out=
df_path=
dict_annotation=
name_file=

rows_show=
selected_svs=
def create_imagen(
    outdir, rows_show, selected_svs, df_out, df_path, dict_annotation, name_file
):
